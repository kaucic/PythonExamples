# %%
# Import numpy for numerical operations and random for random choices
import numpy as np
import random

# %%
# State encoding, board display, and move generation functions
# - convert_to_b3 and convert_from_b3 convert between integer and board string representations
# - print_state displays the board in a human-readable format
# - generate_next_states returns all possible next board states for a given player
# - explore, guided_explore, and exploit implement different move selection strategies for the agent
# - is_win checks if a player has won in a given state
from typing import List, Optional

def convert_to_b3(number: int) -> str:
    """
    Convert an integer state to a base-3 string representation for the Tic-Tac-Toe board.
    Each digit represents a cell: ' ' (empty), 'O', or 'X'.
    Args:
        number (int): The integer state to convert.
    Returns:
        str: A 9-character string representing the board.
    """
    digits = " OX"
    result = ""
    base = 3
    while number > 0:
        result = digits[number % base] + result
        number //= base
    # Prepend leading spaces to make it 9 trigits.
    while len(result) < 9:
        result = digits[0] + result
    return result

def convert_from_b3(code: str) -> int:
    """
    Convert a base-3 string representation of the board to an integer state.
    Args:
        code (str): A 9-character string representing the board.
    Returns:
        int: The integer state corresponding to the board.
    """
    digits = " OX"
    result = 0
    base = 3
    for i in range(9):
        result += digits.index(code[i]) * (base ** (8 - i))
    return result

def print_state(state: int) -> None:
    """
    Print the Tic-Tac-Toe board in a human-readable format.
    Args:
        state (int): The integer state to display.
    Returns:
        None
    """
    def print_row(row):
        vert = ""
        for c in row:
            print(vert + c, end="")
            vert = "|"
    code = convert_to_b3(state)
    horiz = ""
    for i in range(3):
        if len(horiz) != 0:
            print(horiz)
        row = code[i*3:i*3+3]
        print_row(row)
        print()
        horiz = 5*"-"

def generate_next_states(state: int, player: str = "X") -> List[int]:
    """
    Generate all possible next board states for the given player.
    Args:
        state (int): The current board state as an integer.
        player (str): The player to move ('X' or 'O').
    Returns:
        list: List of integer states representing possible next moves.
    """
    code = convert_to_b3(state)
    next_states = []
    for i in range(9):
        if code[i] == " ":
            new_code = code[:i] + player + code[i+1:]
            next_states.append(convert_from_b3(new_code))
    return next_states

def explore(state: int, player: str = "X") -> int:
    """
    Randomly select the next state (exploration).
    Args:
        state (int): The current board state as an integer.
        player (str): The player to move ('X' or 'O').
    Returns:
        int: The next state chosen at random.
    """
    next_states = generate_next_states(state, player)
    return random.choice(next_states)

def guided_explore(state: int, p: 'np.ndarray', player: str = "X") -> int:
    """
    Select the next state based on win probabilities (guided exploration).
    Args:
        state (int): The current board state as an integer.
        p (np.ndarray): Array of win probabilities for each state.
        player (str): The player to move ('X' or 'O').
    Returns:
        int: The next state chosen probabilistically.
    """
    next_states = generate_next_states(state, player)
    if len(next_states) == 0:
        return state
    if player == "X":
        pp = p[next_states]
    else:
        pp = 1 - p[next_states]
    random_index = random.choices(range(len(next_states)), weights=pp)[0]
    random_state = next_states[random_index]
    return random_state

def exploit(state: int, p: 'np.ndarray', player: str = "X") -> int:
    """
    Select the best next state based on win probabilities (exploitation).
    Args:
        state (int): The current board state as an integer.
        p (np.ndarray): Array of win probabilities for each state.
        player (str): The player to move ('X' or 'O').
    Returns:
        int: The next state with the highest win probability.
    """
    next_states = generate_next_states(state, player)
    if len(next_states) == 0:
        return state
    if player == "X":
        pp = p[next_states]
    else:
        pp = 1 - p[next_states]
    best_index = np.argmax(pp)
    best_state = next_states[best_index]
    return best_state
    
def is_win(state: int, player: str = "X") -> Optional[bool]:
    """
    Check if the given player has won in the current state.
    Args:
        state (int): The current board state as an integer.
        player (str): The player to check ('X' or 'O').
    Returns:
        bool: True if the player has won, otherwise None.
    """
    code = convert_to_b3(state)
    # Check rows
    for i in range(3):
        if code[i*3:i*3+3] == 3*player:
            return True
    # Check columns
    for i in range(3):
        if code[i] == code[i+3] == code[i+6] == player:
            return True
    # Check diagonals
    if code[0] == code[4] == code[8] == player:
        return True
    if code[2] == code[4] == code[6] == player:
        return True
    return None

# %%
# Demonstrate how to print the initial, maximum, and a random board state
state = 0
print("First state:", state)
print_state(state)

num_states = 3**9
print("Max state:", num_states - 1)
print_state(num_states - 1)

state = random.randint(0, num_states - 1)
print("Random state:", state)
print_state(state)
# Out:
# First state: 0
#  | |
# -----
#  | |
# -----
#  | |
# Max state: 19682
# X|X|X
# -----
# X|X|X
# -----
# X|X|X
# Random state: 15023
# X| |X
# -----
# O|X|O
# -----
# O| |X

# %%
# Probability initialization and learning loop
# - Initializes the win probability array p for all possible board states
# - Simulates many games, alternating between exploration and exploitation
# - Updates the probability estimates for each state using a simple reinforcement learning update rule

p = np.zeros(num_states)
for i in range(num_states):
    if is_win(i, "X"):
        p[i] = 1.0
    elif is_win(i, "O"):
        p[i] = 0.0
    else:
        p[i] = 0.5

initial_state = 0
visited_states = set()
visited_states.add(initial_state)
num_games = 400_000
p_explore = 0.1
alpha = 0.1
for i in range(num_games):
    if i % (num_games // 10) == 0:
        print("Game", i)
    player = "X"
    state = initial_state
    state_sequence = [state]
    for j in range(9):
        if np.random.rand() < p_explore:
            # Explore
            new_state = explore(state, player)
            #new_state = guided_explore(state, player)
        else:
            # Exploit
            new_state = exploit(state, p, player)
        state = new_state
        state_sequence.append(state)
        visited_states.add(state)
        if is_win(state, player) or j == 8:
            # Update probabilities. p always refers to the probability that "X" wins.
            if player == "X":
                pp = p[state_sequence]
            else:
                pp = 1 - p[state_sequence]
            # pp is the probability that the current player, no matter it is "X" or "O", wins.
            for k in range(len(state_sequence) - 2, -1, -1):
                pp[k] += alpha * (pp[k + 1] - pp[k])
            if player == "X":
                for k in range(len(state_sequence) - 1):
                    p[state_sequence[k]] = pp[k]
            else:
                for k in range(len(state_sequence) - 1):
                    p[state_sequence[k]] = 1 - pp[k]
            break
        if player == "X":
            player = "O"
        else:
            player = "X"
print("Number of visited states:", len(visited_states), "out of", num_states)
# Out:
# Game 0
# Game 40000
# Game 80000
# Game 120000
# Game 160000
# Game 200000
# Game 240000
# Game 280000
# Game 320000
# Game 360000
# Number of visited states: 4618 out of 19683

# %%
# Greedy play example
# Simulates a game where player X always plays optimally (exploits) and player O plays randomly (guided explore)
# Shows the board after each move and announces the winner or a draw
print("Greedy play")
player = "X"
state = 0
print_state(state)
for i in range(9):
    print("Player", player)
    possible_moves = generate_next_states(state, player)
    # If player is "X", make it smart; use only exploit.
    if player == "X":
        state = exploit(state, p, player)
    else:
        # If player is "O", make it dumb; use only explore.
        state = guided_explore(state, p, player)
    print("Player's move:")
    print_state(state)
    if is_win(state, player):
        print(player, "wins!")
        break
    if i == 8:
        print("Draw!")
        break
    if player == "X":
        player = "O"
    else:
        player = "X"
# Out:
# Greedy play
#  | |
# -----
#  | |
# -----
#  | |
# Player X
# Player's move:
#  | |
# -----
#  |X|
# -----
#  | |
# Player O
# Player's move:
#  | |
# -----
#  |X|
# -----
# O| |
# Player X
# Player's move:
#  | |
# -----
# X|X|
# -----
# O| |
# Player O
# Player's move:
#  | |
# -----
# X|X|O
# -----
# O| |
# Player X
# Player's move:
#  | |
# -----
# X|X|O
# -----
# O| |X
# Player O
# Player's move:
# O| |
# -----
# X|X|O
# -----
# O| |X
# Player X
# Player's move:
# O|X|
# -----
# X|X|O
# -----
# O| |X
# Player O
# Player's move:
# O|X|
# -----
# X|X|O
# -----
# O|O|X
# Player X
# Player's move:
# O|X|X
# -----
# X|X|O
# -----
# O|O|X
# Draw!

# %%
# State value visualization
# Prints the learned value (probability of X winning) for a selection of board states, using the trained probability array

def print_state_value(code):
    state = convert_from_b3(code)
    print("Value for code " + str(p[state]) + "\t|" + code + "|")

code_array= [
    "         ",
    "    X    ",
    "X        ",
    "  X      ",
    " X       ",
    "    XO   ",
    "    X O  ",
    "  X XO   ",
    "  X X O  ",
    "  O X XO ",
    "O O X X  ",
    "OXO X XO ",
    "OX XXO O ",
    "OX XXO OX",
    "OXXXXO O ",
    "OX XXOXO "
    ]
for code in code_array:
    print_state_value(code)
# Out:
# Value for code 0.5810337946503348	|         |
# Value for code 0.5806271841582269	|    X    |
# Value for code 0.5492575526349035	|X        |
# Value for code 0.5206271113143567	|  X      |
# Value for code 0.5199573665850553	| X       |
# Value for code 0.9048505199381682	|    XO   |
# Value for code 0.6137386222791459	|    X O  |
# Value for code 0.9596039571870364	|  X XO   |
# Value for code 0.5539676506261548	|  X X O  |
# Value for code 0.9670124548490576	|  O X XO |
# Value for code 0.5400774502674761	|O O X X  |
# Value for code 0.5096039030070951	|OXO X XO |
# Value for code 0.5185949338905086	|OX XXO O |
# Value for code 0.5	|OX XXO OX|
# Value for code 0.5084951915951227	|OXXXXO O |
# Value for code 0.5002428148213728	|OX XXOXO |
